# %%
import os

import numpy as np

import matplotlib.pyplot as plt

import tensorflow as tf
import keras
from keras.models import Model
from keras.layers import Input, Conv2D, LeakyReLU, BatchNormalization, Concatenate, Conv2DTranspose, Dropout

from PIL import Image

# %%
# задаём константы
IMG_WIDTH = 640                       # Ширина итогового изображения
IMG_LENGTH = 768                      # Длина итогового изображения
IMG_SHAPE  = (IMG_WIDTH, IMG_LENGTH)  # Формат изображения (ширина, длина)
CLASSES = 6                           # Число классов сегментирования

# %%
def download_data(path):
    data = []
    for path_image in sorted(os.listdir(path=path)):
        image = Image.open(path + path_image) #Открываем изображение.
        image = tf.image.resize(image, IMG_SHAPE)
        data.append(np.array(image)) #Загружаем пиксели.
    return data

# %%
X_train = download_data("train/images/")
Y_train = download_data("train/masks/")

# %%
X_test = download_data("test/images/")
Y_test = download_data("test/masks/")

# %% [markdown]
# ### Функции предобработки и пост обработки данных

# %%
# Атрибут palette используется для установки цвета полос. Это помогает различать данные
palette = {0: (60, 16, 152), # Building
           1: (132, 41, 246), # Land
           2: (110, 193, 228), # Road
           3: (254, 221, 58), # Vegetation
           4: (226, 169, 41), # Water|
           5: (155, 155, 155)} # Unlabeled

# %%
# Переменная invert_palette позволяет проводить обратное преобразование, цвета в метку класса
invert_palette = {v: k for k, v in palette.items()}

# %%
# сегментация нейронной сети в RGB изображение
def convert_to_color(arr_2d, palette=palette):
    """ Numeric labels to RGB-color encoding """
    arr_3d = np.zeros((arr_2d.shape[0], arr_2d.shape[1], 3), dtype=np.uint8)
    
    for c, i in palette.items():
        m = arr_2d == c
        arr_3d[m] = i
    
    return arr_3d

# %%
# функция преобразует результат сегментации нейронной сети в RGB изображение, удобное для восприятия пользователя
def convert_from_color(arr_3d, palette=invert_palette):
    """ RGB-color encoding to grayscale labels """
    arr_2d = np.zeros((arr_3d.shape[0], arr_3d.shape[1]), dtype=np.uint8)

    # принадлежность каждого пикселя классу
    arr_2d = np.zeros((arr_3d.shape[0], arr_3d.shape[1]), dtype=np.int8)
    # расстояние до ближайшего класса для пикселей
    min_distance = np.zeros((arr_3d.shape[0], arr_3d.shape[1]), dtype=np.float32)+1000
    for c, i in palette.items():
        # ищем расстояние для каждого пикселя до проверяемого класса по евклиду рас-ие
        distance = np.sum((arr_3d - np.array(c).reshape(1, 1, 3))**2, axis=-1)**(1/2)
        # поиск элементов меньше min_distance
        condition = min_distance > distance
        # замена дистанции найденных элементов
        min_distance[condition] = distance[condition]
        # замена класса найденных элементов
        arr_2d[condition] = i

    for c, i in palette.items():
        m = np.all(arr_3d == np.array(c).reshape(1, 1, 3), axis=2)
        arr_2d[m] = i

    arr_2d = arr_2d.tolist()
    for i in range(len(arr_2d)):
        for j in range(len(arr_2d[0])):
            label = [0, 0, 0, 0, 0, 0]
            label[arr_2d[i][j]] = 1
            arr_2d[i][j] = label
    arr_2d = np.array(arr_2d)

    return arr_2d

# %% [markdown]
# ### Предобработка исходных изображений и сегментированных изображений в ответ сети

# %%
# Следующий блок кода подготавливает данные для использования нейронной сетью
X_train_pred = np.array(X_train).reshape([7, IMG_WIDTH, IMG_LENGTH, 3])/255 
X_test_pred = np.array(X_test).reshape([2, IMG_WIDTH, IMG_LENGTH, 3])/255

# %%
Y_train_pred = []
for i in range(len(Y_train)):
    Y_train_pred.append(convert_from_color(Y_train[i][:, :, :3]))
Y_train_pred = np.array(Y_train_pred)

# %%
Y_test_pred = []
for i in range(len(Y_test)):
    Y_test_pred.append(convert_from_color(Y_test[i][:, :, :3]))
Y_test_pred = np.array(Y_test_pred)

# %%
X_train_pred.shape
# Out:
# (7, 640, 768, 3)

# %% [markdown]
# ### Объявление топологии нейронной сети, компиляция и обучение

# %%
def unet_model(image_size, output_classes):

    #Входной слой
    input_layer = Input(shape=image_size + (3,))
    conv_1 = Conv2D(64, 4, 
                    activation=LeakyReLU(),
                    strides=2, 
                    padding='same', 
                    kernel_initializer='glorot_normal', 
                    use_bias=False)(input_layer)
    
    #Сворачиваем
    conv_1_1 = Conv2D(128, 4, 
                      activation=LeakyReLU(), 
                      strides=2, 
                      padding='same', 
                      kernel_initializer='glorot_normal', 
                      use_bias=False)(conv_1)
    batch_norm_1 = BatchNormalization()(conv_1_1)

    #2
    conv_2 = Conv2D(256, 4, 
                    activation=LeakyReLU(), 
                    strides=2, 
                    padding='same', 
                    kernel_initializer='glorot_normal', 
                    use_bias=False)(batch_norm_1)
    batch_norm_2 = BatchNormalization()(conv_2)

    #3
    conv_3 = Conv2D(512, 4, 
                    activation=LeakyReLU(), 
                    strides=2, 
                    padding='same', 
                    kernel_initializer='glorot_normal', 
                    use_bias=False)(batch_norm_2)
    batch_norm_3 = BatchNormalization()(conv_3)

    #4
    conv_4 = Conv2D(512, 4, 
                    activation=LeakyReLU(), 
                    strides=2, 
                    padding='same', 
                    kernel_initializer='glorot_normal', 
                    use_bias=False)(batch_norm_3)
    batch_norm_4 = BatchNormalization()(conv_4)

    #5
    conv_5 = Conv2D(512, 4, 
                    activation=LeakyReLU(), 
                    strides=2, 
                    padding='same', 
                    kernel_initializer='glorot_normal', 
                    use_bias=False)(batch_norm_4)
    batch_norm_5 = BatchNormalization()(conv_5)

    #6
    conv_6 = Conv2D(512, 4, 
                    activation=LeakyReLU(), 
                    strides=2, 
                    padding='same', 
                    kernel_initializer='glorot_normal', 
                    use_bias=False)(batch_norm_5)

    #Разворачиваем
    #1
    up_1 = Concatenate()([
        Conv2DTranspose(512, 4, 
                         activation='relu', 
                         strides=2, 
                         padding='same', 
                         kernel_initializer='glorot_normal', 
                         use_bias=False)(conv_6), 
        conv_5
    ])
    batch_up_1 = BatchNormalization()(up_1)

    #Добавим Dropout от переобучения
    batch_up_1 = Dropout(0.25)(batch_up_1)

    #2
    up_2 = Concatenate()([
        Conv2DTranspose(512, 4, 
                        activation='relu', 
                        strides=2, 
                        padding='same', 
                        kernel_initializer='glorot_normal', 
                        use_bias=False)(batch_up_1), 
        conv_4
    ])
    batch_up_2 = BatchNormalization()(up_2)
    batch_up_2 = Dropout(0.25)(batch_up_2)

    #3
    up_3 = Concatenate()([
        Conv2DTranspose(512, 4, 
                        activation='relu', 
                        strides=2, 
                        padding='same', 
                        kernel_initializer='glorot_normal', 
                        use_bias=False)(batch_up_2), 
        conv_3
    ])
    batch_up_3 = BatchNormalization()(up_3)
    batch_up_3 = Dropout(0.25)(batch_up_3)

    #4
    up_4 = Concatenate()([
        Conv2DTranspose(256, 4, 
                        activation='relu', 
                        strides=2, 
                        padding='same', 
                        kernel_initializer='glorot_normal', 
                        use_bias=False)(batch_up_3), 
        conv_2
    ])
    batch_up_4 = BatchNormalization()(up_4)

    #5
    up_5 = Concatenate()([
        Conv2DTranspose(128, 4, 
                        activation='relu', 
                        strides=2, 
                        padding='same', 
                        kernel_initializer='glorot_normal', 
                        use_bias=False)(batch_up_4), 
        conv_1_1
    ])
    batch_up_5 = BatchNormalization()(up_5)

    #6
    up_6 = Concatenate()([
        Conv2DTranspose(64, 4, 
                        activation='relu', 
                        strides=2, 
                        padding='same', 
                        kernel_initializer='glorot_normal', 
                        use_bias=False)(batch_up_5), 
        conv_1
    ])
    batch_up_6 = BatchNormalization()(up_6)

    #Выходной слой
    output_layer = Conv2DTranspose(output_classes, 4, 
                                   activation='sigmoid', 
                                   strides=2, 
                                   padding='same', 
                                   kernel_initializer='glorot_normal')(batch_up_6)

    model = Model(inputs=input_layer, outputs=output_layer)
    
    return model

# %%
model = unet_model(image_size=IMG_SHAPE, output_classes=CLASSES)

# %%
#Компилируем модель
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 640, 768, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 320, 384, 64  3072        ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 160, 192, 12  131072      ['conv2d[0][0]']
#                                 8)
#
#  batch_normalization (BatchNorm  (None, 160, 192, 12  512        ['conv2d_1[0][0]']
#  alization)                     8)
#
#  conv2d_2 (Conv2D)              (None, 80, 96, 256)  524288      ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 80, 96, 256)  1024       ['conv2d_2[0][0]']
#  rmalization)
#
#  conv2d_3 (Conv2D)              (None, 40, 48, 512)  2097152     ['batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 40, 48, 512)  2048       ['conv2d_3[0][0]']
#  rmalization)
#
#  conv2d_4 (Conv2D)              (None, 20, 24, 512)  4194304     ['batch_normalization_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 20, 24, 512)  2048       ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 10, 12, 512)  4194304     ['batch_normalization_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 10, 12, 512)  2048       ['conv2d_5[0][0]']
#  rmalization)
#
#  conv2d_6 (Conv2D)              (None, 5, 6, 512)    4194304     ['batch_normalization_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 10, 12, 512)  4194304    ['conv2d_6[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 10, 12, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'conv2d_5[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 10, 12, 1024  4096       ['concatenate[0][0]']
#  rmalization)                   )
#
#  dropout (Dropout)              (None, 10, 12, 1024  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_transpose_1 (Conv2DTran  (None, 20, 24, 512)  8388608    ['dropout[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 20, 24, 1024  0           ['conv2d_transpose_1[0][0]',
#                                 )                                 'conv2d_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 20, 24, 1024  4096       ['concatenate_1[0][0]']
#  rmalization)                   )
#
#  dropout_1 (Dropout)            (None, 20, 24, 1024  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_transpose_2 (Conv2DTran  (None, 40, 48, 512)  8388608    ['dropout_1[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 40, 48, 1024  0           ['conv2d_transpose_2[0][0]',
#                                 )                                 'conv2d_3[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 40, 48, 1024  4096       ['concatenate_2[0][0]']
#  rmalization)                   )
#
#  dropout_2 (Dropout)            (None, 40, 48, 1024  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 80, 96, 256)  4194304    ['dropout_2[0][0]']
#  spose)
#
#  concatenate_3 (Concatenate)    (None, 80, 96, 512)  0           ['conv2d_transpose_3[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 80, 96, 512)  2048       ['concatenate_3[0][0]']
#  rmalization)
#
#  conv2d_transpose_4 (Conv2DTran  (None, 160, 192, 12  1048576    ['batch_normalization_8[0][0]']
#  spose)                         8)
#
#  concatenate_4 (Concatenate)    (None, 160, 192, 25  0           ['conv2d_transpose_4[0][0]',
#                                 6)                                'conv2d_1[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 160, 192, 25  1024       ['concatenate_4[0][0]']
#  rmalization)                   6)
#
#  conv2d_transpose_5 (Conv2DTran  (None, 320, 384, 64  262144     ['batch_normalization_9[0][0]']
#  spose)                         )
#
#  concatenate_5 (Concatenate)    (None, 320, 384, 12  0           ['conv2d_transpose_5[0][0]',
#                                 8)                                'conv2d[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 320, 384, 12  512        ['concatenate_5[0][0]']
#  ormalization)                  8)
#
#  conv2d_transpose_6 (Conv2DTran  (None, 640, 768, 6)  12294      ['batch_normalization_10[0][0]']
#  spose)
#
# ==================================================================================================
# Total params: 41,850,886
# Trainable params: 41,839,110
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %%
# Обучаем модель
history = model.fit(X_train_pred,
                    Y_train_pred,
                    batch_size=1,
                    epochs=100,
                    validation_data=(X_test_pred, Y_test_pred))
# Out:
# Epoch 1/100
# 7/7 [==============================] - 10s 1s/step - loss: 1.5332 - accuracy: 0.4534 - val_loss: 42.0137 - val_accuracy: 0.2556
# Epoch 2/100
# 7/7 [==============================] - 8s 1s/step - loss: 1.1991 - accuracy: 0.6756 - val_loss: 835.2107 - val_accuracy: 0.2559
# Epoch 3/100
# 7/7 [==============================] - 8s 1s/step - loss: 1.0593 - accuracy: 0.7006 - val_loss: 1245.1648 - val_accuracy: 0.2558
# Epoch 4/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.9711 - accuracy: 0.7078 - val_loss: 812.8378 - val_accuracy: 0.2554
# Epoch 5/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.9169 - accuracy: 0.7214 - val_loss: 371.7437 - val_accuracy: 0.2558
# Epoch 6/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.9018 - accuracy: 0.7245 - val_loss: 263.1996 - val_accuracy: 0.2541
# Epoch 7/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.8665 - accuracy: 0.7257 - val_loss: 394.0961 - val_accuracy: 0.2413
# Epoch 8/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.9277 - accuracy: 0.7216 - val_loss: 2033.8326 - val_accuracy: 0.1278
# Epoch 9/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.8721 - accuracy: 0.7410 - val_loss: 1964.5219 - val_accuracy: 0.1713
# Epoch 10/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.8375 - accuracy: 0.7408 - val_loss: 1232.2805 - val_accuracy: 0.1758
# Epoch 11/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.7671 - accuracy: 0.7653 - val_loss: 427.0236 - val_accuracy: 0.0669
# Epoch 12/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.7457 - accuracy: 0.7706 - val_loss: 140.3451 - val_accuracy: 0.1480
# Epoch 13/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.7028 - accuracy: 0.7718 - val_loss: 88.5746 - val_accuracy: 0.0786
# Epoch 14/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.6717 - accuracy: 0.7888 - val_loss: 37.2493 - val_accuracy: 0.0364
# Epoch 15/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.6265 - accuracy: 0.8017 - val_loss: 21.1161 - val_accuracy: 0.0398
# Epoch 16/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.6002 - accuracy: 0.8119 - val_loss: 9.4272 - val_accuracy: 0.1117
# Epoch 17/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.5589 - accuracy: 0.8292 - val_loss: 5.7466 - val_accuracy: 0.1557
# Epoch 18/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.5326 - accuracy: 0.8292 - val_loss: 4.2456 - val_accuracy: 0.2085
# Epoch 19/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.4890 - accuracy: 0.8535 - val_loss: 1.9469 - val_accuracy: 0.3801
# Epoch 20/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.4572 - accuracy: 0.8621 - val_loss: 1.6559 - val_accuracy: 0.4679
# Epoch 21/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.4679 - accuracy: 0.8574 - val_loss: 2.5272 - val_accuracy: 0.3377
# Epoch 22/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.4541 - accuracy: 0.8583 - val_loss: 1.7200 - val_accuracy: 0.4361
# Epoch 23/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.4437 - accuracy: 0.8572 - val_loss: 1.9218 - val_accuracy: 0.3905
# Epoch 24/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.4368 - accuracy: 0.8595 - val_loss: 2.3575 - val_accuracy: 0.2472
# Epoch 25/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.3860 - accuracy: 0.8790 - val_loss: 2.3374 - val_accuracy: 0.3119
# Epoch 26/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.3538 - accuracy: 0.8907 - val_loss: 3.3384 - val_accuracy: 0.1415
# Epoch 27/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.3239 - accuracy: 0.8984 - val_loss: 2.2862 - val_accuracy: 0.2914
# Epoch 28/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.3145 - accuracy: 0.8967 - val_loss: 3.1537 - val_accuracy: 0.2190
# Epoch 29/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.3007 - accuracy: 0.9035 - val_loss: 3.1018 - val_accuracy: 0.2035
# Epoch 30/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.2863 - accuracy: 0.9078 - val_loss: 2.7792 - val_accuracy: 0.2596
# Epoch 31/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.2656 - accuracy: 0.9128 - val_loss: 2.1022 - val_accuracy: 0.3897
# Epoch 32/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.2428 - accuracy: 0.9205 - val_loss: 2.5092 - val_accuracy: 0.3052
# Epoch 33/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.2362 - accuracy: 0.9225 - val_loss: 2.0214 - val_accuracy: 0.4192
# Epoch 34/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.2408 - accuracy: 0.9190 - val_loss: 2.5137 - val_accuracy: 0.2765
# Epoch 35/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.2491 - accuracy: 0.9181 - val_loss: 1.9625 - val_accuracy: 0.5467
# Epoch 36/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.2310 - accuracy: 0.9224 - val_loss: 2.9606 - val_accuracy: 0.2330
# Epoch 37/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.2381 - accuracy: 0.9211 - val_loss: 2.3736 - val_accuracy: 0.3817
# Epoch 38/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.2239 - accuracy: 0.9246 - val_loss: 2.4402 - val_accuracy: 0.3521
# Epoch 39/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.2090 - accuracy: 0.9310 - val_loss: 2.6161 - val_accuracy: 0.2925
# Epoch 40/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.2025 - accuracy: 0.9327 - val_loss: 2.6577 - val_accuracy: 0.2724
# Epoch 41/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1842 - accuracy: 0.9386 - val_loss: 2.2814 - val_accuracy: 0.3781
# Epoch 42/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1758 - accuracy: 0.9419 - val_loss: 2.5850 - val_accuracy: 0.2568
# Epoch 43/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1672 - accuracy: 0.9439 - val_loss: 2.0068 - val_accuracy: 0.5096
# Epoch 44/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1630 - accuracy: 0.9454 - val_loss: 2.3309 - val_accuracy: 0.3709
# Epoch 45/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1541 - accuracy: 0.9487 - val_loss: 2.0520 - val_accuracy: 0.5084
# Epoch 46/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1532 - accuracy: 0.9480 - val_loss: 2.2729 - val_accuracy: 0.3920
# Epoch 47/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1520 - accuracy: 0.9480 - val_loss: 1.8120 - val_accuracy: 0.5729
# Epoch 48/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1487 - accuracy: 0.9491 - val_loss: 1.9905 - val_accuracy: 0.4033
# Epoch 49/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1420 - accuracy: 0.9518 - val_loss: 1.8738 - val_accuracy: 0.5484
# Epoch 50/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1320 - accuracy: 0.9555 - val_loss: 1.9908 - val_accuracy: 0.4862
# Epoch 51/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1334 - accuracy: 0.9549 - val_loss: 1.4278 - val_accuracy: 0.5774
# Epoch 52/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1327 - accuracy: 0.9534 - val_loss: 1.7686 - val_accuracy: 0.5725
# Epoch 53/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1394 - accuracy: 0.9526 - val_loss: 1.3957 - val_accuracy: 0.6023
# Epoch 54/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1439 - accuracy: 0.9503 - val_loss: 1.2500 - val_accuracy: 0.6195
# Epoch 55/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1450 - accuracy: 0.9503 - val_loss: 2.0124 - val_accuracy: 0.5815
# Epoch 56/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1425 - accuracy: 0.9519 - val_loss: 1.7522 - val_accuracy: 0.5469
# Epoch 57/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1636 - accuracy: 0.9450 - val_loss: 2.0498 - val_accuracy: 0.5804
# Epoch 58/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1397 - accuracy: 0.9533 - val_loss: 1.1353 - val_accuracy: 0.6925
# Epoch 59/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1283 - accuracy: 0.9560 - val_loss: 1.2671 - val_accuracy: 0.6237
# Epoch 60/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1204 - accuracy: 0.9590 - val_loss: 1.0698 - val_accuracy: 0.7239
# Epoch 61/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1149 - accuracy: 0.9607 - val_loss: 1.2375 - val_accuracy: 0.6122
# Epoch 62/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1066 - accuracy: 0.9633 - val_loss: 1.0223 - val_accuracy: 0.7389
# Epoch 63/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1025 - accuracy: 0.9642 - val_loss: 1.0226 - val_accuracy: 0.7363
# Epoch 64/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1000 - accuracy: 0.9652 - val_loss: 1.0532 - val_accuracy: 0.7295
# Epoch 65/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1030 - accuracy: 0.9635 - val_loss: 0.9535 - val_accuracy: 0.7730
# Epoch 66/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1105 - accuracy: 0.9609 - val_loss: 0.9803 - val_accuracy: 0.7521
# Epoch 67/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1028 - accuracy: 0.9638 - val_loss: 0.9637 - val_accuracy: 0.7598
# Epoch 68/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1011 - accuracy: 0.9649 - val_loss: 0.9053 - val_accuracy: 0.8061
# Epoch 69/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1016 - accuracy: 0.9641 - val_loss: 1.1125 - val_accuracy: 0.6828
# Epoch 70/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0997 - accuracy: 0.9649 - val_loss: 0.9570 - val_accuracy: 0.7985
# Epoch 71/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1018 - accuracy: 0.9637 - val_loss: 0.9975 - val_accuracy: 0.7603
# Epoch 72/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0995 - accuracy: 0.9645 - val_loss: 0.8549 - val_accuracy: 0.8204
# Epoch 73/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1085 - accuracy: 0.9604 - val_loss: 1.0282 - val_accuracy: 0.7715
# Epoch 74/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1144 - accuracy: 0.9595 - val_loss: 1.1718 - val_accuracy: 0.7002
# Epoch 75/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1108 - accuracy: 0.9609 - val_loss: 0.8592 - val_accuracy: 0.8146
# Epoch 76/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1159 - accuracy: 0.9586 - val_loss: 1.1375 - val_accuracy: 0.6806
# Epoch 77/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1058 - accuracy: 0.9623 - val_loss: 0.8344 - val_accuracy: 0.8180
# Epoch 78/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0944 - accuracy: 0.9668 - val_loss: 0.9790 - val_accuracy: 0.7584
# Epoch 79/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0876 - accuracy: 0.9690 - val_loss: 1.1675 - val_accuracy: 0.6704
# Epoch 80/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0821 - accuracy: 0.9711 - val_loss: 0.8480 - val_accuracy: 0.8271
# Epoch 81/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0813 - accuracy: 0.9712 - val_loss: 0.8108 - val_accuracy: 0.8410
# Epoch 82/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0786 - accuracy: 0.9721 - val_loss: 0.8475 - val_accuracy: 0.8286
# Epoch 83/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0770 - accuracy: 0.9725 - val_loss: 0.8280 - val_accuracy: 0.8384
# Epoch 84/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0773 - accuracy: 0.9722 - val_loss: 0.8362 - val_accuracy: 0.8417
# Epoch 85/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0775 - accuracy: 0.9725 - val_loss: 0.8385 - val_accuracy: 0.8403
# Epoch 86/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0746 - accuracy: 0.9732 - val_loss: 0.8501 - val_accuracy: 0.8517
# Epoch 87/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0771 - accuracy: 0.9724 - val_loss: 0.8558 - val_accuracy: 0.8329
# Epoch 88/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0776 - accuracy: 0.9716 - val_loss: 0.8331 - val_accuracy: 0.8538
# Epoch 89/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0826 - accuracy: 0.9697 - val_loss: 0.8423 - val_accuracy: 0.8480
# Epoch 90/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0783 - accuracy: 0.9716 - val_loss: 0.8602 - val_accuracy: 0.8430
# Epoch 91/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0815 - accuracy: 0.9706 - val_loss: 0.8979 - val_accuracy: 0.8575
# Epoch 92/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0734 - accuracy: 0.9734 - val_loss: 0.8709 - val_accuracy: 0.8394
# Epoch 93/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0824 - accuracy: 0.9699 - val_loss: 0.9077 - val_accuracy: 0.8542
# Epoch 94/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0805 - accuracy: 0.9700 - val_loss: 0.9423 - val_accuracy: 0.8303
# Epoch 95/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0747 - accuracy: 0.9729 - val_loss: 0.9315 - val_accuracy: 0.8389
# Epoch 96/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0774 - accuracy: 0.9722 - val_loss: 0.9487 - val_accuracy: 0.8561
# Epoch 97/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0787 - accuracy: 0.9713 - val_loss: 0.9550 - val_accuracy: 0.8198
# Epoch 98/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0817 - accuracy: 0.9707 - val_loss: 1.0048 - val_accuracy: 0.8356
# Epoch 99/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0916 - accuracy: 0.9669 - val_loss: 0.9148 - val_accuracy: 0.8544
# Epoch 100/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0996 - accuracy: 0.9661 - val_loss: 0.8636 - val_accuracy: 0.8546

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Точность модели')
plt.ylabel('точность')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left');

# %% [markdown]
# ### predict для двух тестовых картинок

# %%
# Делаем сегментацию для двух тестовых картинок
out = model.predict(X_test_pred[:2], batch_size=1)
# Out:
# 2/2 [==============================] - 1s 268ms/step

# %%
# 2-е тестовые картинки
for i in range(2):
    plt.subplot(1, 2, i+1)
    plt.imshow(convert_to_color(np.argmax(Y_test_pred[i], axis=-1)))
plt.suptitle('Тестовая сегментация', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show();

# 2-е картинки полученые методом predict
for i in range(2):
    plt.subplot(1, 2, i+1)
    plt.imshow(convert_to_color(np.argmax(out[i], axis=-1)))
plt.suptitle('Полученная сегментация', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show();

# %% [markdown]
# Точность модели 0.8546 при 100 эпохах обучения.
# Полученный результат сегментации очень похож на тестовый.
